# %%
from IPython.display import Image
from os import chdir

chdir("C:\\Users\\Fredrik\\Documents\\GitHub\\Hubert-Final-Project\\project")

# %%
Image(filename='Levels/assets/Level 2.png', width=600)
